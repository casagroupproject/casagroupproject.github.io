# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
from matplotlib.dates import date2num, DayLocator, DateFormatter, MonthLocator

pd.set_option('display.max_rows', 200)
# %matplotlib inline

# %%
#initialize google map API
from geopy import geocoders

# %%
g = geocoders.GoogleV3("AIzaSyCqTMWCA9KPXuNoBfNsd6e2UiMkOgavPDY")

# %%
g.geocode("Spain")
# Out:
# Location(Spain, (40.46366700000001, -3.74922, 0.0))

# %%
dataL=pd.read_csv('dataAverage.csv')
# Out:
# /Users/shu/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dataL.head(2)
# Out:
#    Latitude  Longitude  LimitingMag                   Country Unnamed: 4
# 0   42.2301   -89.0416            5  United States - Illinois        NaN
# 1   51.7887     6.0575            4                   Germany        NaN

# %%
dataL.groupby(['Country']).LimitingMag.mean()
# Out:
# Country
# Afghanistan                               5.461538
# Aland Islands                             7.000000
# Albania                                   4.200000
# Algeria                                   3.435714
# Andorra                                   2.000000
# Angola                                    3.500000
# Antarctica                                3.478261
# Argentina                                 3.209662
# Armenia                                   1.000000
# Aruba                                     4.333333
# Australia                                -0.117647
# Austria                                  -8.367033
# Azerbaijan                                4.500000
# Bahrain                                   3.290323
# Bangladesh                             -196.800000
# Barbados                                  4.000000
# Belarus                                   5.000000
# Belgium                                  -1.501894
# ...

# %%
dataDes=dataL.groupby('Country')['LimitingMag'].describe()

#                          limitingMag.summary()df.groupby('Category')['Score'].describe()

# %%
dataDes1=dataL.groupby('Country').describe()

# %%
countryList=dataDes1.index.tolist()

# %%
len(countryList)
# Out:
# 236

# %%
dataDes.head(3)
# Out:
#                count      mean       std  min  25%  50%  75%  max
# Country
# Afghanistan     13.0  5.461538  0.967418  4.0  5.0  5.0  6.0  7.0
# Aland Islands    1.0  7.000000       NaN  7.0  7.0  7.0  7.0  7.0
# Albania          5.0  4.200000  2.049390  2.0  2.0  5.0  6.0  6.0

# %%
type(dataDes)
# Out:
# pandas.core.frame.DataFrame

# %%
dataDes.head(0)
# Out:
# Empty DataFrame
# Columns: [count, mean, std, min, 25%, 50%, 75%, max]
# Index: []

# %%
#here we use median to eliminate the effect of the extreme value
dataDes=dataDes['50%']

# %%
dataDes.tail(4)
# Out:
# Country
# Yemen            3.5
# Zambia           4.0
# Zimbabwe         6.0
# timezone: CST    2.5
# Name: 50%, dtype: float64

# %%
magList=dataDes.tolist()

# %%
#print out all the processed light data as target format, exported to js file
for i in range(0,235):
                  placemark = g.geocode(countryList[i])
                  print ('{lat:',placemark[1][0],', lng:',placemark[1][1],',','label:"',
                         countryList[i],magList[i],'"}',',')
# Out:
# {lat: 33.93911 , lng: 67.709953 , label:" Afghanistan 5.0 "} ,
# {lat: 60.1785247 , lng: 19.9156105 , label:" Aland Islands 7.0 "} ,
# {lat: 41.153332 , lng: 20.168331 , label:" Albania 5.0 "} ,
# {lat: 28.033886 , lng: 1.659626 , label:" Algeria 4.0 "} ,
# {lat: 42.506285 , lng: 1.521801 , label:" Andorra 2.0 "} ,
# {lat: -11.202692 , lng: 17.873887 , label:" Angola 3.5 "} ,
# {lat: -82.862752 , lng: 135.0 , label:" Antarctica 3.0 "} ,
# {lat: -38.416097 , lng: -63.61667199999999 , label:" Argentina 4.0 "} ,
# {lat: 40.069099 , lng: 45.038189 , label:" Armenia 1.0 "} ,
# {lat: 12.52111 , lng: -69.968338 , label:" Aruba 5.0 "} ,
# {lat: -25.274398 , lng: 133.775136 , label:" Australia 4.0 "} ,
# {lat: 47.516231 , lng: 14.550072 , label:" Austria 5.0 "} ,
# {lat: 40.143105 , lng: 47.576927 , label:" Azerbaijan 4.5 "} ,
# {lat: 26.0667 , lng: 50.5577 , label:" Bahrain 3.0 "} ,
# {lat: 23.684994 , lng: 90.356331 , label:" Bangladesh 3.0 "} ,
# ...
